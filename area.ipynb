# %% [markdown]
# <a href="https://colab.research.google.com/github/Anast2007/Assignment-AIML/blob/main/area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("maheshmani13/world-population-growth")
# Out:
# ...
# 100%|██████████| 1.58k/1.58k [00:00<00:00, 1.70MB/s]
# Extracting files...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               73 non-null     int64
#  1   Population         73 non-null     object
#  2   Yearly Growth %    73 non-null     object
#  3   Number             73 non-null     object
#  4   Density (Pop/km2)  73 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 3.0+ KB

# %%
import pandas as pd
import os

# Define the path to the CSV file
file_path = os.path.join(new_folder_path, 'World Population Growth.csv')

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#    Year     Population Yearly Growth %      Number  Density (Pop/km2)
# 0  1951  2,543,130,380           1.75%  43,808,223                 17
# 1  1952  2,590,270,899           1.85%  47,140,519                 17
# 2  1953  2,640,278,797           1.93%  50,007,898                 18
# 3  1954  2,691,979,339           1.96%  51,700,542                 18
# 4  1955  2,746,072,141           2.01%  54,092,802                 18

# %%
import os

# List the contents of the downloaded dataset directory
dataset_files = os.listdir(path)
print(f"Contents of the dataset directory '{path}':")
for file_name in dataset_files:
    print(file_name)
# Out:
# Contents of the dataset directory '/root/.cache/kagglehub/datasets/maheshmani13/world-population-growth/versions/1':

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 7))
sns.barplot(x='Year', y='Population', data=df)
plt.title('World Population Over Years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df['Population'] = df['Population'].str.replace(',', '').astype(float)
df['Number'] = df['Number'].str.replace(',', '').astype(float)
df['Yearly Growth %'] = df['Yearly Growth %'].str.replace('%', '').astype(float) / 100

print("Data types after cleaning:")
df.info()
# Out:
# Data types after cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               73 non-null     int64
#  1   Population         73 non-null     float64
#  2   Yearly Growth %    73 non-null     float64
#  3   Number             73 non-null     float64
#  4   Density (Pop/km2)  73 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 3.0 KB

# %%
display(df.head())
# Out:
#    Year    Population  Yearly Growth %      Number  Density (Pop/km2)
# 0  1951  2.543130e+09           0.0175  43808223.0                 17
# 1  1952  2.590271e+09           0.0185  47140519.0                 17
# 2  1953  2.640279e+09           0.0193  50007898.0                 18
# 3  1954  2.691979e+09           0.0196  51700542.0                 18
# 4  1955  2.746072e+09           0.0201  54092802.0                 18
